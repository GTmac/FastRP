# %% [markdown]
# # Init

# %%
# %matplotlib inline

import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2

# %%
plt.style.use('ggplot')

# %%
plt.rcParams['font.size'] = 11
plt.rcParams['figure.autolayout'] = True

# %% [markdown]
# # Blogcatalog

# %%
fastrp_macro = {0.1: 0.2342, 0.2: 0.2516, 0.3: 0.2591, 0.4: 0.2692, 0.5: 0.2753,
               0.6: 0.2795, 0.7: 0.2870, 0.8: 0.2880, 0.9: 0.2969}
randne_macro = {0.1: 0.2088, 0.2: 0.2312, 0.3: 0.2461, 0.4: 0.2541, 0.5: 0.2588,
               0.6: 0.2690, 0.7: 0.2721, 0.8: 0.2730, 0.9: 0.2759}
deepwalk_macro = {0.1: 0.2130, 0.2: 0.2380, 0.3: 0.2530, 0.4: 0.2630, 0.5: 0.2730,
               0.6: 0.2760, 0.7: 0.2790, 0.8: 0.2820, 0.9: 0.2890}
line_macro = {0.1: 0.1963, 0.2: 0.2304, 0.3: 0.2452, 0.4: 0.2570, 0.5: 0.2665,
               0.6: 0.2726, 0.7: 0.2794, 0.8: 0.2834, 0.9: 0.2887}
node2vec_macro = {0.1: 0.2144, 0.2: 0.2413, 0.3: 0.2590, 0.4: 0.2704, 0.5: 0.2770,
               0.6: 0.2810, 0.7: 0.2845, 0.8: 0.2899, 0.9: 0.2989}

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
# ax.set_xlim(0.00, 0.10)
# ax.set_ylim(0.55, 0.70)

metric = r'Macro $F_1$ Score'
p = pd.DataFrame(fastrp_macro, index=[metric]).transpose()
ax.plot(p.index, p[metric], linewidth=1.5, marker='v')

p = pd.DataFrame(randne_macro, index=[metric]).transpose()
ax.plot(p.index, p[metric], linewidth=1.5, marker='o')

p = pd.DataFrame(deepwalk_macro, index=[metric]).transpose()
ax.plot(p.index, p[metric], linewidth=1.5, marker='s')

p = pd.DataFrame(line_macro, index=[metric]).transpose()
ax.plot(p.index, p[metric], linewidth=1.5, marker='3')

p = pd.DataFrame(node2vec_macro, index=[metric]).transpose()
ax.plot(p.index, p[metric], linewidth=1.5, marker='+')

ax.set_xlabel('Fraction of Labeled Data')
ax.set_ylabel('Blogcatalog', fontsize=20)
handles, labels = ax.get_legend_handles_labels()
ax.legend(loc=4, labels=['FastRP', 'RandNE', 'DeepWalk', 'LINE', 'node2vec'])

fig.savefig('figures/blog-f1.pdf')

# %% [markdown]
# # Flickr

# %%
fastrp_macro = {0.01: 0.1502, 0.02: 0.1848, 0.03: 0.2007, 0.04: 0.2143, 0.05: 0.2250,
               0.06: 0.2321, 0.07: 0.2374, 0.08: 0.2415, 0.09: 0.2462}
randne_macro = {0.01: 0.1364, 0.02: 0.1689, 0.03: 0.1914, 0.04: 0.2064, 0.05: 0.2159,
               0.06: 0.2232, 0.07: 0.2300, 0.08: 0.2355, 0.09: 0.2395}
deepwalk_macro = {0.01: 0.1400, 0.02: 0.1730, 0.03: 0.1960, 0.04: 0.2110, 0.05: 0.2210,
               0.06: 0.2290, 0.07: 0.2360, 0.08: 0.2410, 0.09: 0.2460}
line_macro = {0.01: 0.1069, 0.02: 0.1301, 0.03: 0.1463, 0.04: 0.1576, 0.05: 0.1652,
               0.06: 0.1735, 0.07: 0.1805, 0.08: 0.1868, 0.09: 0.1915}
node2vec_macro = {0.01: 0.1189, 0.02: 0.1603, 0.03: 0.1822, 0.04: 0.1976, 0.05: 0.2094,
               0.06: 0.2223, 0.07: 0.2305, 0.08: 0.2375, 0.09: 0.2436}

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
# ax.set_xlim(0.00, 0.10)
# ax.set_ylim(0.55, 0.70)

metric = r'Macro $F_1$ Score'
p = pd.DataFrame(fastrp_macro, index=[metric]).transpose()
ax.plot(p.index, p[metric], linewidth=1.5, marker='v')

p = pd.DataFrame(randne_macro, index=[metric]).transpose()
ax.plot(p.index, p[metric], linewidth=1.5, marker='o')

p = pd.DataFrame(deepwalk_macro, index=[metric]).transpose()
ax.plot(p.index, p[metric], linewidth=1.5, marker='s')

p = pd.DataFrame(line_macro, index=[metric]).transpose()
ax.plot(p.index, p[metric], linewidth=1.5, marker='3')

p = pd.DataFrame(node2vec_macro, index=[metric]).transpose()
ax.plot(p.index, p[metric], linewidth=1.5, marker='+')

ax.set_xlabel('Fraction of Labeled Data')
ax.set_ylabel('Flickr', fontsize=20)
handles, labels = ax.get_legend_handles_labels()
ax.legend(loc=4, labels=['FastRP', 'RandNE', 'DeepWalk', 'LINE', 'node2vec'])

fig.savefig('figures/flickr-f1.pdf')

# %% [markdown]
# # WWW-10K

# %%
fastrp_macro = {0.01: 0.2692, 0.02: 0.3534, 0.03: 0.4459, 0.04: 0.4978, 0.05: 0.5421,
               0.06: 0.5952, 0.07: 0.6494, 0.08: 0.6851, 0.09: 0.7109}
randne_macro = {0.01: 0.1568, 0.02: 0.1903, 0.03: 0.2259, 0.04: 0.2958, 0.05: 0.3366,
               0.06: 0.3698, 0.07: 0.3976, 0.08: 0.4105, 0.09: 0.4508}
deepwalk_macro = {0.01: 0.2554, 0.02: 0.3761, 0.03: 0.4496, 0.04: 0.4996, 0.05: 0.5398,
               0.06: 0.5789, 0.07: 0.6114, 0.08: 0.6291, 0.09: 0.6782}
line_macro = {0.01: 0.0666, 0.02: 0.0907, 0.03: 0.0998, 0.04: 0.1077, 0.05: 0.1224,
               0.06: 0.1295, 0.07: 0.1337, 0.08: 0.1360, 0.09: 0.1420}
node2vec_macro = {0.01: 0.2742, 0.02: 0.3590, 0.03: 0.4404, 0.04: 0.5047, 0.05: 0.5529,
               0.06: 0.6045, 0.07: 0.6615, 0.08: 0.6730, 0.09: 0.7026}

# %%
fig = plt.figure(figsize=(6,4))
ax = fig.add_subplot(111)
# ax.set_xlim(0.00, 0.10)
# ax.set_ylim(0.55, 0.70)

metric = r'Macro $F_1$ Score'
p = pd.DataFrame(fastrp_macro, index=[metric]).transpose()
ax.plot(p.index, p[metric], linewidth=1.5, marker='v')

p = pd.DataFrame(randne_macro, index=[metric]).transpose()
ax.plot(p.index, p[metric], linewidth=1.5, marker='o')

p = pd.DataFrame(deepwalk_macro, index=[metric]).transpose()
ax.plot(p.index, p[metric], linewidth=1.5, marker='s')

p = pd.DataFrame(line_macro, index=[metric]).transpose()
ax.plot(p.index, p[metric], linewidth=1.5, marker='3')

p = pd.DataFrame(node2vec_macro, index=[metric]).transpose()
ax.plot(p.index, p[metric], linewidth=1.5, marker='+')

ax.set_xlabel('Fraction of Labeled Data')
ax.set_ylabel('WWW-10K', fontsize=20)
handles, labels = ax.get_legend_handles_labels()
ax.legend(loc=4, labels=['FastRP', 'RandNE', 'DeepWalk', 'LINE', 'node2vec'])

fig.savefig('figures/www-f1.pdf')
